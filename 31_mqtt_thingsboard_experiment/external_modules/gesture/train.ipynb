# %% [markdown]
# ##### 01 数据集导入，创建训练集和测试集。通过查看注释，理解整个流程。

# %%
import glob
import numpy as np
# 训练集、测试集划分
from sklearn.model_selection import train_test_split
# 数据集相对路径
DATA_PATH = "../../../10_tingml_datasets/"
# LABELS 的内容尽量与前面store_data.py保持一致
LABELS = ["Stationary", "Tilted", "Rotating", "Moving"]
# 代表一个样本内容，如连续10次传感器读到的6轴数据作为一个样本
SAMPLES_PER_GESTURE = 10
def load_one_label_data(label):
    path = DATA_PATH + label + "*.npy"
    files = glob.glob(path)
    datas = []
    for file in files:
        try:
            data = np.load(file)
            # 切除多余数据，如数据当中有61份，但每个样本只需要10份，那么最后一份需要丢弃。
            num_slice = len(data) // SAMPLES_PER_GESTURE
            datas.append(data[: num_slice * SAMPLES_PER_GESTURE, :])
        except Exception as e:
            print(e)
    datas = np.concatenate(datas, axis=0)
    # 由于本案例给的是全连接层，输入为1维数据。(其余如conv需要自行根据模型输入修改尺寸，如二维)
    # MLP
    # datas = np.reshape(datas,(-1, 6 * SAMPLES_PER_GESTURE,),)  # Modified here
    # CNN 1
    datas = np.reshape(datas,(-1, 6 * SAMPLES_PER_GESTURE, 1),)  # Modified here
    idx = LABELS.index(label)
    labels = np.ones(datas.shape[0]) * idx
    return datas, labels
all_datas = []
all_labels = []
# 导入每个label对应的数据
for label in LABELS:
    datas, labels = load_one_label_data(label)
    all_datas.append(datas)
    all_labels.append(labels)
dataX = np.concatenate(all_datas, axis=0)
dataY = np.concatenate(all_labels, axis=0)
# 输入和样本到此创建完毕

# 训练集、测试集划分
# test_size 表示数据集里面有20%将划分给测试集
# stratify=dataY指定按label进行划分, 确保数据集划分公平
xTrain, xTest, yTrain, yTest = train_test_split(
    dataX, dataY, test_size=0.2, stratify=dataY
)
print(xTrain.shape, xTest.shape, yTrain.shape, yTest.shape)
# Out:
# (800, 60, 1) (200, 60, 1) (800,) (200,)

# %% [markdown]
# ##### 02 模型创建
# 下面将创建很简单的多层感知机模型，后续可自行定义模型结构。需要根据自身需求，自行上网查询其他模型，如CNN，切记模型不要太大，嵌入式设备大致提供32K空间供运行模型。
# 模型需要注意输入尺寸，如CNN往往多维数据，如**Conv1d 输入二维，可将输入改为(6 * SAMPLES_PER_GESTURE,1)或者(SAMPLES_PER_GESTURE, 6), 上面数据集对应尺寸也需要修改**

# %%
import os
# 0 = INFO, 1 = WARNING, 2 = ERROR, 3 = FATAL
os.environ['TF_CPP_MIN_LOG_LEVEL'] = '2'
import tensorflow as tf
import tensorflow.keras as keras
SAMPLES_PER_GESTURE = 10
LABELS = ["Stationary", "Tilted", "Rotating", "Moving"]

# 设置环境变量，控制日志级别
def mlp():
    # 一个用于线性堆叠多个网络层的模型。
    # Sequential模型是最简单的神经网络模型，它按照层的顺序依次堆叠，每一层的输出会成为下一层的输入。
    model = keras.Sequential()
    # 第一层, 添加全连接层，输出尺寸为64，激活函数采用"relu"
    # 第一层需要制定输入大小，这里和数据集对应input_shape=(6 * SAMPLES_PER_GESTURE,)
    model.add(keras.layers.Dense(64, activation="relu", input_shape=(6 * SAMPLES_PER_GESTURE,)))
    # 添加池化层，防止模型过拟合，每次自动忘记20%的参数
    model.add(keras.layers.Dropout(0.2))
    # 最后一层，全连接层，输出尺寸对应labels数量，激活函数采用"softmax"
    # softmaxs输出的结果代表每个label的概率，如第0个代表label 0的概率
    model.add(keras.layers.Dense(len(LABELS), activation="softmax"))
    return model
def cnn():
    # 一个用于线性堆叠多个网络层的模型。
    # Sequential模型是最简单的神经网络模型，它按照层的顺序依次堆叠，每一层的输出会成为下一层的输入。
    model = keras.Sequential()
    # 注意CNN与MLP的输入shape
    # 16个输出通道，3为卷积核大小
    model.add(
        keras.layers.Conv1D(
            8,3,padding="same",activation="relu",input_shape=(6 * SAMPLES_PER_GESTURE, 1),
        )
    )
    model.add(keras.layers.Conv1D(8, 3, padding="same", activation="relu"))
    model.add(keras.layers.GlobalAveragePooling1D())
    model.add(keras.layers.Dense(16, activation="relu"))
    model.add(keras.layers.Dropout(0.2))
    model.add(keras.layers.Dense(len(LABELS), activation="softmax"))
    return model


model = cnn()
# 打印模型结构
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv1d (Conv1D)              (None, 60, 8)             32
# _________________________________________________________________
# conv1d_1 (Conv1D)            (None, 60, 8)             200
# _________________________________________________________________
# global_average_pooling1d (Gl (None, 8)                 0
# _________________________________________________________________
# dense (Dense)                (None, 16)                144
# _________________________________________________________________
# dropout (Dropout)            (None, 16)                0
# _________________________________________________________________
# dense_1 (Dense)              (None, 4)                 68
# =================================================================
# Total params: 444
# Trainable params: 444
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# ##### 03 模型训练及测试

# %%
from tensorflow.keras.callbacks import ModelCheckpoint
# 加载模型
from tensorflow.keras.models import load_model
# 测试模型性能
from sklearn.metrics import confusion_matrix
# 模型训练优化器，学习率为0.001
optimizer = keras.optimizers.Adam(lr=0.001)
# 制定模型优化器，和损失函数、评价指标
model.compile(
    loss="sparse_categorical_crossentropy",
    optimizer=optimizer,
    metrics=["sparse_categorical_accuracy"],
)
# 制定保存模型的路径
filepath = "best_model.h5"
model.save(filepath)
# 训练时，保存最好模型
checkpoint = ModelCheckpoint(
    filepath,
    monitor="val_sparse_categorical_accuracy",
    verbose=1,
    save_best_only=True,
    mode="max",
)
# 模型训练, 训练集，batch_size为批大小，可提高训练速度
# validation_data指明验证集，epochs表示训练迭代轮数
# verbose=1表示打印训练日志
# callbacks调用上述保存模型的方法
history = model.fit(
    xTrain,
    yTrain,
    batch_size=8,
    validation_data=(xTest, yTest),
    epochs=50,
    verbose=1,
    callbacks=[checkpoint],
)
# 至此模型训练完毕
# Out:
# Epoch 1/50
# /home/wjy/.conda/envs/riot/lib/python3.8/site-packages/keras/optimizer_v2/optimizer_v2.py:355: UserWarning: The `lr` argument is deprecated, use `learning_rate` instead.
#   warnings.warn(
# 100/100 [==============================] - 0s 2ms/step - loss: 2.0122 - sparse_categorical_accuracy: 0.2975 - val_loss: 1.1621 - val_sparse_categorical_accuracy: 0.5950
#
# Epoch 00001: val_sparse_categorical_accuracy improved from -inf to 0.59500, saving model to best_model.h5
# Epoch 2/50
# 100/100 [==============================] - 0s 727us/step - loss: 1.2577 - sparse_categorical_accuracy: 0.4762 - val_loss: 1.0869 - val_sparse_categorical_accuracy: 0.6100
#
# Epoch 00002: val_sparse_categorical_accuracy improved from 0.59500 to 0.61000, saving model to best_model.h5
# Epoch 3/50
# 100/100 [==============================] - 0s 678us/step - loss: 1.1338 - sparse_categorical_accuracy: 0.5725 - val_loss: 1.0047 - val_sparse_categorical_accuracy: 0.6400
#
# Epoch 00003: val_sparse_categorical_accuracy improved from 0.61000 to 0.64000, saving model to best_model.h5
# Epoch 4/50
# 100/100 [==============================] - 0s 1ms/step - loss: 1.0223 - sparse_categorical_accuracy: 0.6388 - val_loss: 0.9515 - val_sparse_categorical_accuracy: 0.6350
#
# Epoch 00004: val_sparse_categorical_accuracy did not improve from 0.64000
# Epoch 5/50
# 100/100 [==============================] - 0s 2ms/step - loss: 0.9541 - sparse_categorical_accuracy: 0.6488 - val_loss: 0.8754 - val_sparse_categorical_accuracy: 0.7050
#
# Epoch 00005: val_sparse_categorical_accuracy improved from 0.64000 to 0.70500, saving model to best_model.h5
# Epoch 6/50
# 100/100 [==============================] - 0s 1ms/step - loss: 0.8848 - sparse_categorical_accuracy: 0.6750 - val_loss: 0.8043 - val_sparse_categorical_accuracy: 0.7400
#
# Epoch 00006: val_sparse_categorical_accuracy improved from 0.70500 to 0.74000, saving model to best_model.h5
# Epoch 7/50
# 100/100 [==============================] - 0s 1ms/step - loss: 0.8358 - sparse_categorical_accuracy: 0.7150 - val_loss: 0.7554 - val_sparse_categorical_accuracy: 0.7300
#
# Epoch 00007: val_sparse_categorical_accuracy did not improve from 0.74000
# Epoch 8/50
# 100/100 [==============================] - 0s 1ms/step - loss: 0.7764 - sparse_categorical_accuracy: 0.7075 - val_loss: 0.6969 - val_sparse_categorical_accuracy: 0.7600
#
# Epoch 00008: val_sparse_categorical_accuracy improved from 0.74000 to 0.76000, saving model to best_model.h5
# Epoch 9/50
# 100/100 [==============================] - 0s 1ms/step - loss: 0.7037 - sparse_categorical_accuracy: 0.7387 - val_loss: 0.6320 - val_sparse_categorical_accuracy: 0.7900
#
# Epoch 00009: val_sparse_categorical_accuracy improved from 0.76000 to 0.79000, saving model to best_model.h5
# Epoch 10/50
# 100/100 [==============================] - 0s 2ms/step - loss: 0.6774 - sparse_categorical_accuracy: 0.7500 - val_loss: 0.5906 - val_sparse_categorical_accuracy: 0.7850
#
# Epoch 00010: val_sparse_categorical_accuracy did not improve from 0.79000
# Epoch 11/50
# 100/100 [==============================] - 0s 2ms/step - loss: 0.6346 - sparse_categorical_accuracy: 0.7563 - val_loss: 0.5500 - val_sparse_categorical_accuracy: 0.8150
#
# Epoch 00011: val_sparse_categorical_accuracy improved from 0.79000 to 0.81500, saving model to best_model.h5
# Epoch 12/50
# 100/100 [==============================] - 0s 2ms/step - loss: 0.5914 - sparse_categorical_accuracy: 0.7800 - val_loss: 0.5166 - val_sparse_categorical_accuracy: 0.8250
#
# Epoch 00012: val_sparse_categorical_accuracy improved from 0.81500 to 0.82500, saving model to best_model.h5
# Epoch 13/50
# 100/100 [==============================] - 0s 898us/step - loss: 0.5629 - sparse_categorical_accuracy: 0.7950 - val_loss: 0.4841 - val_sparse_categorical_accuracy: 0.8250
#
# Epoch 00013: val_sparse_categorical_accuracy did not improve from 0.82500
# Epoch 14/50
# 100/100 [==============================] - 0s 1ms/step - loss: 0.5459 - sparse_categorical_accuracy: 0.7950 - val_loss: 0.4604 - val_sparse_categorical_accuracy: 0.8450
#
# Epoch 00014: val_sparse_categorical_accuracy improved from 0.82500 to 0.84500, saving model to best_model.h5
# Epoch 15/50
# 100/100 [==============================] - 0s 627us/step - loss: 0.5462 - sparse_categorical_accuracy: 0.7925 - val_loss: 0.4425 - val_sparse_categorical_accuracy: 0.8400
#
# Epoch 00015: val_sparse_categorical_accuracy did not improve from 0.84500
# Epoch 16/50
# 100/100 [==============================] - 0s 1ms/step - loss: 0.5014 - sparse_categorical_accuracy: 0.8150 - val_loss: 0.4173 - val_sparse_categorical_accuracy: 0.8400
#
# Epoch 00016: val_sparse_categorical_accuracy did not improve from 0.84500
# Epoch 17/50
# 100/100 [==============================] - 0s 1ms/step - loss: 0.4864 - sparse_categorical_accuracy: 0.8125 - val_loss: 0.4000 - val_sparse_categorical_accuracy: 0.8450
#
# Epoch 00017: val_sparse_categorical_accuracy did not improve from 0.84500
# Epoch 18/50
# 100/100 [==============================] - 0s 1ms/step - loss: 0.4521 - sparse_categorical_accuracy: 0.8363 - val_loss: 0.3767 - val_sparse_categorical_accuracy: 0.8450
#
# Epoch 00018: val_sparse_categorical_accuracy did not improve from 0.84500
# Epoch 19/50
# 100/100 [==============================] - 0s 1ms/step - loss: 0.4568 - sparse_categorical_accuracy: 0.8238 - val_loss: 0.3652 - val_sparse_categorical_accuracy: 0.8450
#
# Epoch 00019: val_sparse_categorical_accuracy did not improve from 0.84500
# Epoch 20/50
# 100/100 [==============================] - 0s 637us/step - loss: 0.4140 - sparse_categorical_accuracy: 0.8288 - val_loss: 0.3471 - val_sparse_categorical_accuracy: 0.8400
#
# Epoch 00020: val_sparse_categorical_accuracy did not improve from 0.84500
# Epoch 21/50
# 100/100 [==============================] - 0s 1ms/step - loss: 0.3973 - sparse_categorical_accuracy: 0.8313 - val_loss: 0.3408 - val_sparse_categorical_accuracy: 0.8450
#
# Epoch 00021: val_sparse_categorical_accuracy did not improve from 0.84500
# Epoch 22/50
# 100/100 [==============================] - 0s 1ms/step - loss: 0.3955 - sparse_categorical_accuracy: 0.8350 - val_loss: 0.3128 - val_sparse_categorical_accuracy: 0.8400
#
# Epoch 00022: val_sparse_categorical_accuracy did not improve from 0.84500
# Epoch 23/50
# 100/100 [==============================] - 0s 1ms/step - loss: 0.3593 - sparse_categorical_accuracy: 0.8450 - val_loss: 0.2899 - val_sparse_categorical_accuracy: 0.8450
#
# Epoch 00023: val_sparse_categorical_accuracy did not improve from 0.84500
# Epoch 24/50
# 100/100 [==============================] - 0s 990us/step - loss: 0.3722 - sparse_categorical_accuracy: 0.8462 - val_loss: 0.3010 - val_sparse_categorical_accuracy: 0.8450
#
# Epoch 00024: val_sparse_categorical_accuracy did not improve from 0.84500
# Epoch 25/50
# 100/100 [==============================] - 0s 1ms/step - loss: 0.3278 - sparse_categorical_accuracy: 0.8675 - val_loss: 0.2571 - val_sparse_categorical_accuracy: 0.8450
#
# Epoch 00025: val_sparse_categorical_accuracy did not improve from 0.84500
# Epoch 26/50
# 100/100 [==============================] - 0s 1ms/step - loss: 0.3178 - sparse_categorical_accuracy: 0.8737 - val_loss: 0.2629 - val_sparse_categorical_accuracy: 0.8400
#
# Epoch 00026: val_sparse_categorical_accuracy did not improve from 0.84500
# Epoch 27/50
# 100/100 [==============================] - 0s 1ms/step - loss: 0.2995 - sparse_categorical_accuracy: 0.8788 - val_loss: 0.2467 - val_sparse_categorical_accuracy: 0.8400
#
# Epoch 00027: val_sparse_categorical_accuracy did not improve from 0.84500
# Epoch 28/50
# 100/100 [==============================] - 0s 2ms/step - loss: 0.2845 - sparse_categorical_accuracy: 0.9137 - val_loss: 0.2196 - val_sparse_categorical_accuracy: 0.8400
#
# Epoch 00028: val_sparse_categorical_accuracy did not improve from 0.84500
# Epoch 29/50
# 100/100 [==============================] - 0s 778us/step - loss: 0.2854 - sparse_categorical_accuracy: 0.9175 - val_loss: 0.2060 - val_sparse_categorical_accuracy: 0.9900
#
# Epoch 00029: val_sparse_categorical_accuracy improved from 0.84500 to 0.99000, saving model to best_model.h5
# Epoch 30/50
# 100/100 [==============================] - 0s 629us/step - loss: 0.2749 - sparse_categorical_accuracy: 0.9187 - val_loss: 0.2137 - val_sparse_categorical_accuracy: 0.9850
#
# Epoch 00030: val_sparse_categorical_accuracy did not improve from 0.99000
# Epoch 31/50
# 100/100 [==============================] - 0s 1ms/step - loss: 0.2518 - sparse_categorical_accuracy: 0.9400 - val_loss: 0.2081 - val_sparse_categorical_accuracy: 0.8400
#
# Epoch 00031: val_sparse_categorical_accuracy did not improve from 0.99000
# Epoch 32/50
# 100/100 [==============================] - 0s 2ms/step - loss: 0.2324 - sparse_categorical_accuracy: 0.9375 - val_loss: 0.1780 - val_sparse_categorical_accuracy: 0.9850
#
# Epoch 00032: val_sparse_categorical_accuracy did not improve from 0.99000
# Epoch 33/50
# 100/100 [==============================] - 0s 1ms/step - loss: 0.2345 - sparse_categorical_accuracy: 0.9287 - val_loss: 0.1675 - val_sparse_categorical_accuracy: 0.9900
#
# Epoch 00033: val_sparse_categorical_accuracy did not improve from 0.99000
# Epoch 34/50
# 100/100 [==============================] - 0s 668us/step - loss: 0.2323 - sparse_categorical_accuracy: 0.9312 - val_loss: 0.1556 - val_sparse_categorical_accuracy: 0.9850
#
# Epoch 00034: val_sparse_categorical_accuracy did not improve from 0.99000
# Epoch 35/50
# 100/100 [==============================] - 0s 1ms/step - loss: 0.2039 - sparse_categorical_accuracy: 0.9413 - val_loss: 0.1647 - val_sparse_categorical_accuracy: 0.9900
#
# Epoch 00035: val_sparse_categorical_accuracy did not improve from 0.99000
# Epoch 36/50
# 100/100 [==============================] - 0s 1ms/step - loss: 0.2093 - sparse_categorical_accuracy: 0.9262 - val_loss: 0.1479 - val_sparse_categorical_accuracy: 0.9900
#
# Epoch 00036: val_sparse_categorical_accuracy did not improve from 0.99000
# Epoch 37/50
# 100/100 [==============================] - 0s 765us/step - loss: 0.1753 - sparse_categorical_accuracy: 0.9525 - val_loss: 0.1263 - val_sparse_categorical_accuracy: 0.9950
#
# Epoch 00037: val_sparse_categorical_accuracy improved from 0.99000 to 0.99500, saving model to best_model.h5
# Epoch 38/50
# 100/100 [==============================] - 0s 1ms/step - loss: 0.2098 - sparse_categorical_accuracy: 0.9275 - val_loss: 0.1417 - val_sparse_categorical_accuracy: 0.9900
#
# Epoch 00038: val_sparse_categorical_accuracy did not improve from 0.99500
# Epoch 39/50
# 100/100 [==============================] - 0s 1ms/step - loss: 0.1854 - sparse_categorical_accuracy: 0.9425 - val_loss: 0.1231 - val_sparse_categorical_accuracy: 0.9900
#
# Epoch 00039: val_sparse_categorical_accuracy did not improve from 0.99500
# Epoch 40/50
# 100/100 [==============================] - 0s 975us/step - loss: 0.1776 - sparse_categorical_accuracy: 0.9488 - val_loss: 0.1136 - val_sparse_categorical_accuracy: 0.9900
#
# Epoch 00040: val_sparse_categorical_accuracy did not improve from 0.99500
# Epoch 41/50
# 100/100 [==============================] - 0s 1ms/step - loss: 0.1573 - sparse_categorical_accuracy: 0.9550 - val_loss: 0.1103 - val_sparse_categorical_accuracy: 0.9900
#
# Epoch 00041: val_sparse_categorical_accuracy did not improve from 0.99500
# Epoch 42/50
# 100/100 [==============================] - 0s 2ms/step - loss: 0.1714 - sparse_categorical_accuracy: 0.9475 - val_loss: 0.1014 - val_sparse_categorical_accuracy: 0.9900
#
# Epoch 00042: val_sparse_categorical_accuracy did not improve from 0.99500
# Epoch 43/50
# 100/100 [==============================] - 0s 2ms/step - loss: 0.1596 - sparse_categorical_accuracy: 0.9513 - val_loss: 0.0942 - val_sparse_categorical_accuracy: 0.9950
#
# Epoch 00043: val_sparse_categorical_accuracy did not improve from 0.99500
# Epoch 44/50
# 100/100 [==============================] - 0s 1ms/step - loss: 0.1605 - sparse_categorical_accuracy: 0.9563 - val_loss: 0.0895 - val_sparse_categorical_accuracy: 0.9900
#
# Epoch 00044: val_sparse_categorical_accuracy did not improve from 0.99500
# Epoch 45/50
# 100/100 [==============================] - 0s 1ms/step - loss: 0.1463 - sparse_categorical_accuracy: 0.9688 - val_loss: 0.0886 - val_sparse_categorical_accuracy: 0.9900
#
# Epoch 00045: val_sparse_categorical_accuracy did not improve from 0.99500
# Epoch 46/50
# 100/100 [==============================] - 0s 1ms/step - loss: 0.1416 - sparse_categorical_accuracy: 0.9525 - val_loss: 0.0804 - val_sparse_categorical_accuracy: 0.9900
#
# Epoch 00046: val_sparse_categorical_accuracy did not improve from 0.99500
# Epoch 47/50
# 100/100 [==============================] - 0s 1ms/step - loss: 0.1310 - sparse_categorical_accuracy: 0.9812 - val_loss: 0.0761 - val_sparse_categorical_accuracy: 0.9900
#
# Epoch 00047: val_sparse_categorical_accuracy did not improve from 0.99500
# Epoch 48/50
# 100/100 [==============================] - 0s 2ms/step - loss: 0.1331 - sparse_categorical_accuracy: 0.9688 - val_loss: 0.0661 - val_sparse_categorical_accuracy: 0.9950
#
# Epoch 00048: val_sparse_categorical_accuracy did not improve from 0.99500
# Epoch 49/50
# 100/100 [==============================] - 0s 2ms/step - loss: 0.1194 - sparse_categorical_accuracy: 0.9762 - val_loss: 0.0637 - val_sparse_categorical_accuracy: 0.9900
#
# Epoch 00049: val_sparse_categorical_accuracy did not improve from 0.99500
# Epoch 50/50
# 100/100 [==============================] - 0s 2ms/step - loss: 0.1358 - sparse_categorical_accuracy: 0.9725 - val_loss: 0.0542 - val_sparse_categorical_accuracy: 0.9950
#
# Epoch 00050: val_sparse_categorical_accuracy did not improve from 0.99500

# %%
# 加载模型
model = load_model(filepath)
# 模型推理，预测
predictions = model.predict(xTest)
predictions = np.argmax(predictions, axis=1)
# 查看混淆矩阵，效果越好，预测则集中在对角线。
cm = confusion_matrix(yTest, predictions)
print(cm)
# Out:
# [[30  0  0  0]
#  [ 0 80  0  0]
#  [ 0  0 39  1]
#  [ 0  0  0 50]]

# %% [markdown]
# 由于运动状态简单，上述最简单的模型可能也会获得不错的性能，当运动状态变得复杂，上述MLP模型性能将很难满足需求。
# #### 04 生成最终部署的模型
# 由于RIOT系统使用的时tflite-micro库且资源有限，将模型量化，并保存成tflite-micro可识别的格式，注意
# `data_test = np.reshape(data_test, (-1, 6 * SAMPLES_PER_GESTURE, ))`后的尺寸维度和大小需要和前面大致对应

# %%
# Convert the model to the TensorFlow Lite format with quantization
# 加载模型
model = load_model(filepath)
converter = tf.lite.TFLiteConverter.from_keras_model(model)
tflite_model = converter.convert()
# 保存初始版本，后续对比用
open("model_basic.tflite", "wb").write(tflite_model)
open("model.tflite", "wb").write(tflite_model)

# 量化模型, 定义输入格式与大小，只需要修改(-1, 6 * SAMPLES_PER_GESTURE,)与上面对应即可，其余不用变
data_test = xTest.astype("float32")
# np.reshape 和一开始数据集导入对应
# MLP
# data_test = np.reshape(data_test, (-1, 6 * SAMPLES_PER_GESTURE, ))
# CNN 1
data_test = np.reshape(data_test, (-1, 6 * SAMPLES_PER_GESTURE, 1))
data_ds = tf.data.Dataset.from_tensor_slices((data_test)).batch(1)
# Rest of your code...
def representative_data_gen():
    for input_value in data_ds.take(100):
        yield [input_value]
converter.representative_dataset = representative_data_gen
converter.optimizations = [tf.lite.Optimize.OPTIMIZE_FOR_SIZE]
tflite_model = converter.convert()
open("model.tflite", "wb").write(tflite_model)

# 量化前后对比
basic_model_size = os.path.getsize("model_basic.tflite")
print("Basic model is %d bytes" % basic_model_size)
quantized_model_size = os.path.getsize("model.tflite")
print("Quantized model is %d bytes" % quantized_model_size)
difference = basic_model_size - quantized_model_size
print("Difference is %d bytes" % difference)
# Out:
# INFO:tensorflow:Assets written to: /tmp/tmpvtmcb50n/assets
# WARNING:absl:Optimization option OPTIMIZE_FOR_SIZE is deprecated, please use optimizations=[Optimize.DEFAULT] instead.
# INFO:tensorflow:Assets written to: /tmp/tmpylxv0hnn/assets
# INFO:tensorflow:Assets written to: /tmp/tmpylxv0hnn/assets
# WARNING:absl:Optimization option OPTIMIZE_FOR_SIZE is deprecated, please use optimizations=[Optimize.DEFAULT] instead.
# WARNING:absl:Optimization option OPTIMIZE_FOR_SIZE is deprecated, please use optimizations=[Optimize.DEFAULT] instead.
# Basic model is 5672 bytes
# Quantized model is 5720 bytes
# Difference is -48 bytes
# fully_quantize: 0, inference_type: 6, input_inference_type: 0, output_inference_type: 0

# %% [markdown]
# 前面，通过量化，帮助我们模型节省了2440Bytes大小。需要验证量化后的模型输入格式和尺寸是否正确

# %%
# Now let's verify the model on a few input digits
# Instantiate an interpreter for the model
model_quantized_reloaded = tf.lite.Interpreter("model.tflite")

# Allocate memory for each model
model_quantized_reloaded.allocate_tensors()

# Get the input and output tensors so we can feed in values and get the results
model_quantized_input = model_quantized_reloaded.get_input_details()[0]["index"]
model_quantized_output = model_quantized_reloaded.get_output_details()[0]["index"]
# Create arrays to store the results
model_quantized_predictions = np.empty(xTest.size)
for i in range(20):
    # Reshape the data and ensure the type is float32
    # test_data = np.reshape(
    #     xTest[i],
    #     (
    #         1,
    #         6 * SAMPLES_PER_GESTURE,
    #         1,
    #     ),
    # ).astype("float32")
    test_data = np.expand_dims(xTest[i], axis=0).astype("float32")
    print(test_data.shape)
    # Invoke the interpreter
    model_quantized_reloaded.set_tensor(model_quantized_input, test_data)
    model_quantized_reloaded.invoke()
    model_quantized_prediction = model_quantized_reloaded.get_tensor(
        model_quantized_output
    )

    print("Digit: {} - Prediction:\n{}".format(yTest[i], model_quantized_prediction))
    print("")
# Out:
# (1, 60, 1)
# Digit: 1.0 - Prediction:
# [[0.         0.984375   0.         0.01171875]]
#
# (1, 60, 1)
# Digit: 1.0 - Prediction:
# [[0.00390625 0.89453125 0.         0.1015625 ]]
#
# (1, 60, 1)
# Digit: 1.0 - Prediction:
# [[0.03125    0.8671875  0.00390625 0.09765625]]
#
# (1, 60, 1)
# Digit: 3.0 - Prediction:
# [[0.         0.         0.         0.99609375]]
#
# (1, 60, 1)
# Digit: 1.0 - Prediction:
# [[0.03515625 0.9296875  0.         0.03515625]]
#
# (1, 60, 1)
# Digit: 3.0 - Prediction:
# [[0.         0.         0.03515625 0.9609375 ]]
#
# (1, 60, 1)
# Digit: 3.0 - Prediction:
# [[0.         0.         0.00390625 0.99609375]]
#
# (1, 60, 1)
# Digit: 3.0 - Prediction:
# [[0.         0.         0.01171875 0.98828125]]
#
# (1, 60, 1)
# Digit: 1.0 - Prediction:
# [[0.         0.99609375 0.         0.        ]]
#
# (1, 60, 1)
# Digit: 0.0 - Prediction:
# [[0.49609375 0.49609375 0.         0.0078125 ]]
#
# (1, 60, 1)
# Digit: 2.0 - Prediction:
# [[0.         0.         0.99609375 0.        ]]
#
# (1, 60, 1)
# Digit: 1.0 - Prediction:
# [[0.49609375 0.49609375 0.         0.0078125 ]]
#
# (1, 60, 1)
# Digit: 1.0 - Prediction:
# [[0.01171875 0.88671875 0.00390625 0.09765625]]
#
# (1, 60, 1)
# Digit: 1.0 - Prediction:
# [[0.01171875 0.94921875 0.         0.03515625]]
#
# (1, 60, 1)
# Digit: 1.0 - Prediction:
# [[0.03515625 0.9296875  0.         0.03515625]]
#
# (1, 60, 1)
# Digit: 3.0 - Prediction:
# [[0.         0.         0.01171875 0.98828125]]
#
# (1, 60, 1)
# Digit: 0.0 - Prediction:
# [[0.49609375 0.49609375 0.         0.0078125 ]]
#
# (1, 60, 1)
# Digit: 3.0 - Prediction:
# [[0.         0.         0.00390625 0.99609375]]
#
# (1, 60, 1)
# Digit: 1.0 - Prediction:
# [[0.         0.984375   0.         0.01171875]]
#
# (1, 60, 1)
# Digit: 3.0 - Prediction:
# [[0.         0.         0.         0.99609375]]
